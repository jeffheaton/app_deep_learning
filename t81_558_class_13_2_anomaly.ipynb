# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_deep_learning/blob/main/t81_558_class_13_2_anomaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 13: Other Techniques**
#
# * Instructor: [Jeff Heaton](https://sites.washu.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.washu.edu/index.html)
# * For more information visit the [class website](https://sites.washu.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 13 Material
#
# * Part 13.1: Autoencoders and Dimensionality Reduction [[Video]]() [[Notebook]](t81_558_class_13_1_auto_encode.ipynb)
# * **Part 13.2: Anomaly Detection** [[Video]]() [[Notebook]](t81_558_class_13_2_anomaly.ipynb)
# * Part 13.3: Reinforcement Learning with TorchRL [[Video]]() [[Notebook]](t81_558_class_13_3_reinforcement.ipynb)
# * Part 13.4: Pruning Neural Networks [[Video]]() [[Notebook]](t81_558_class_13_4_pruning.ipynb)
# * Part 13.5: Self-Supervised Learning [[Video]]() [[Notebook]](t81_558_class_13_5_self_supervised.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code checks that Google CoLab is running and sets up the correct hardware settings for PyTorch.

# %%
try:
    import google.colab
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# Make use of a GPU or MPS (Apple) if one is available.  (see module 2.5)
import torch
has_mps = torch.backends.mps.is_built()
device = "mps" if has_mps else "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Note: not using Google CoLab
# Using device: mps

# %% [markdown]
# # Part 13.2: Anomaly Detection
#
# Anomaly detection is the task of identifying data points that differ markedly from the norm: the fraudulent transaction among millions of legitimate ones, the failing machine among healthy ones, the intrusion among ordinary network traffic. What makes the problem distinctive is that anomalies are, by definition, rare and varied. You usually cannot collect a representative training set of them, and the next anomaly may look nothing like the last. This rules out treating detection as ordinary supervised classification, where you would need many labeled examples of every class you hope to recognize.
#
# The way around this is to model only what *normal* looks like, and then flag anything that does not fit. An autoencoder is well suited to this. If you train an autoencoder exclusively on normal data, it becomes good at reconstructing normal examples through its bottleneck, but it has never learned to represent anomalies. When an anomaly arrives, the network reconstructs it poorly, and the **reconstruction error**, the difference between the input and the autoencoder's output, spikes. That error is an anomaly score: low for normal points, high for outliers.
#
# This section builds a reconstruction-based anomaly detector, drawing directly on the autoencoder from the previous section. We treat one group of digits as normal, train an autoencoder on them alone, and show that images from a different, unseen digit produce reconstruction errors large enough to separate them from the normal data. We then discuss how to turn that continuous score into a concrete detection threshold.

# %% [markdown]
# ## Approaches to Anomaly Detection
#
# There are several broad families of anomaly-detection methods. **Statistical** methods fit a distribution to the normal data and flag points of low probability. **Distance and density** methods, such as k-nearest-neighbors or Local Outlier Factor, flag points that lie far from their neighbors or in sparse regions. **Reconstruction-based** methods, the focus here, learn to rebuild normal data and flag points that cannot be rebuilt accurately.
#
# The reconstruction approach is especially attractive for high-dimensional data like images or sensor streams, where fitting an explicit probability distribution is hard. An autoencoder learns the shape of the normal data implicitly, in its weights, and reduces the entire question of "is this point unusual" to a single number: how badly it was reconstructed. That number is cheap to compute for any new point and requires no labeled anomalies to define.

# %% [markdown]
# ## Training on Normal Data Only
#
# To demonstrate this, we split the digits dataset into a *normal* class and an *anomalous* class. We treat every digit except one as normal, and hold out a single digit to play the role of the anomaly. Crucially, the autoencoder is trained on the normal digits alone; the anomalous digit is never seen during training. This mimics the real situation, where you have abundant normal data and no reliable sample of the anomalies you will eventually face.

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.preprocessing import MinMaxScaler

torch.manual_seed(42)
np.random.seed(42)

digits = load_digits()
X = MinMaxScaler().fit_transform(digits.data).astype(np.float32)
y = digits.target

# Treat the digit 7 as the anomaly; every other digit is "normal".
ANOMALY = 7
X_normal = X[y != ANOMALY]
X_anomaly = X[y == ANOMALY]
print(f"normal examples:  {len(X_normal)}")
print(f"anomaly examples: {len(X_anomaly)}  (digit {ANOMALY}, unseen in training)")

X_normal_t = torch.tensor(X_normal)


class Autoencoder(nn.Module):
    def __init__(self, n_inputs=64, latent=8):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(n_inputs, 32), nn.ReLU(),
            nn.Linear(32, latent), nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent, 32), nn.ReLU(),
            nn.Linear(32, n_inputs), nn.Sigmoid(),
        )

    def forward(self, x):
        return self.decoder(self.encoder(x))


model = Autoencoder()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

for epoch in range(2000):
    optimizer.zero_grad()
    loss = loss_fn(model(X_normal_t), X_normal_t)
    loss.backward()
    optimizer.step()
    if epoch % 500 == 0 or epoch == 1999:
        print(f"epoch {epoch:4d}   normal reconstruction MSE {loss.item():.4f}")
# Out:
# normal examples:  1618
# anomaly examples: 179  (digit 7, unseen in training)
# epoch    0   normal reconstruction MSE 0.1786
# epoch  500   normal reconstruction MSE 0.0374
# epoch 1000   normal reconstruction MSE 0.0225
# epoch 1500   normal reconstruction MSE 0.0202
# epoch 1999   normal reconstruction MSE 0.0191

# %% [markdown]
# ## Reconstruction Error as an Anomaly Score
#
# With the autoencoder trained on normal digits, we compute the per-image reconstruction error for both the normal data and the held-out anomalous digit. The error is the mean squared difference between each image and its reconstruction. If the approach works, the anomalous digit, which the network never learned to represent, should produce systematically larger errors than the normal digits.

# %%
def reconstruction_error(data):
    x = torch.tensor(data)
    with torch.no_grad():
        recon = model(x)
    return ((recon - x) ** 2).mean(dim=1).numpy()   # per-image MSE


err_normal = reconstruction_error(X_normal)
err_anomaly = reconstruction_error(X_anomaly)

print(f"normal   reconstruction error:  mean {err_normal.mean():.4f}")
print(f"anomaly  reconstruction error:  mean {err_anomaly.mean():.4f}")

plt.figure(figsize=(8, 4.5))
plt.hist(err_normal, bins=40, alpha=0.7, label="normal digits", density=True)
plt.hist(err_anomaly, bins=40, alpha=0.7, label=f"anomaly (digit {ANOMALY})", density=True)
plt.xlabel("reconstruction error (per-image MSE)")
plt.ylabel("density")
plt.title("Reconstruction error separates normal data from anomalies")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# normal   reconstruction error:  mean 0.0191
# anomaly  reconstruction error:  mean 0.0591

# %% [markdown]
# The two histograms are clearly shifted apart: the anomalous digit reconstructs with a substantially higher error than the normal digits, exactly as the method predicts. The network's inability to rebuild something it was never trained on has become a usable detection signal. Note that the separation is not perfect, the distributions overlap at the edges, which is why the final step is choosing where to draw the line.

# %% [markdown]
# ## Choosing a Threshold
#
# To turn the continuous error score into a yes-or-no decision, we set a threshold: any image whose reconstruction error exceeds it is flagged as an anomaly. A common, principled choice is to set the threshold from the *normal* data alone, for example at a high percentile of the normal error distribution, since in practice that is the only data you can trust to be clean. Setting the threshold at the 95th percentile of normal errors, for instance, accepts that about 5 percent of normal points will be false alarms, and then measures how many true anomalies are caught above that line.
#
# Because the anomaly score is a single number and the threshold sweeps across all its values, the quality of the detector across every possible threshold can be summarized with the ROC AUC introduced in Module 11.5. We compute it here to score the detector as a whole.

# %%
from sklearn.metrics import roc_auc_score

# Label anomalies as 1, normal as 0, and use reconstruction error as the score.
scores = np.concatenate([err_normal, err_anomaly])
labels = np.concatenate([np.zeros(len(err_normal)), np.ones(len(err_anomaly))])
auc = roc_auc_score(labels, scores)

# Threshold from the normal data alone: the 95th percentile of normal errors.
threshold = np.percentile(err_normal, 95)
flagged_anomaly = (err_anomaly > threshold).mean()
false_alarm = (err_normal > threshold).mean()

print(f"ROC AUC of the reconstruction-error detector: {auc:.3f}")
print(f"threshold (95th percentile of normal error):  {threshold:.4f}")
print(f"anomalies correctly flagged: {flagged_anomaly:.1%}")
print(f"normal points false-alarmed: {false_alarm:.1%}")
# Out:
# ROC AUC of the reconstruction-error detector: 0.981
# threshold (95th percentile of normal error):  0.0381
# anomalies correctly flagged: 92.7%
# normal points false-alarmed: 5.0%

# %% [markdown]
# The AUC well above 0.5 confirms that reconstruction error ranks anomalies above normal points reliably, and the threshold drawn from the normal distribution catches a large fraction of the true anomalies while holding false alarms near the 5 percent we budgeted for. In a real deployment you would tune that threshold to balance the cost of missed anomalies against the cost of false alarms, precisely the precision-and-recall tradeoff discussed in Module 11.5.
#
# Reconstruction-based detection is powerful because it needs no labeled anomalies, only a clean sample of normal data, and it extends naturally to images, time series, and sensor data. It does assume your training data is truly representative of "normal," and it can miss anomalies that happen to reconstruct well. The next section turns to an entirely different technique, one where a model learns by interacting with an environment rather than reconstructing data: [Reinforcement Learning with TorchRL](t81_558_class_13_3_reinforcement.ipynb).
