# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_deep_learning/blob/main/assignments/assignment_yourname_t81_558_class7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# * Instructor: [Jeff Heaton](https://sites.washu.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.washu.edu/index.html)
# * For more information visit the [class website](https://sites.washu.edu/jeffheaton/t81-558/).
#
# **Module 7 Assignment: Image Processing**
#
# **Student Name: Your Name**

# %% [markdown]
# # Assignment Instructions
#
# For this assignment, you will use two images:
#
# * [Dog House](https://github.com/jeffheaton/t81_558_deep_learning/raw/master/photos/hickory_home.jpg)
# * [Land Scape](https://github.com/jeffheaton/t81_558_deep_learning/raw/master/photos/landscape.jpg)
#
#
# Your code should work with any image; however, these are the two that the **submit** function is expecting.  The goal is to convert both images to a square size.  In this module, we saw how to transform a square by cropping.  This time, we will switch to a square by adding space.  If an image is [landscape orientation](https://en.wikipedia.org/wiki/Page_orientation), you will need to add space at the top and bottom.  Similarly, for a portrait (taller than wide), you will add space at the sides.  Make sure that your program centers the image between the spaces.
#
# The following diagram illustrates this.
#
# ![Image Processing Instructions](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/image-instructions.png "Image Processing Instructions")
#
# To calculate the color to add to the new space, take the average of all RGB values.  Essentially, sum all the red values, green, and blue, and divide by the total number of pixels.  Notice how the darker landscape picture above has a darker color added to the above/below space?  This effect is due to this averaging.  Make sure you convert your average RGB values to integers; RGB values do not have fractional components.
#
# The submit function checks whether your height and width match my solution.  Your height and width should be square and match my dimensions.  If this is not the case, you likely have a problem with your assignment.
#
# The submit function also takes three pixels and tests them.  Pixels 1 and 3 are the upper-left and lower-right; these are the average colors and should match my solution exactly. You might see a difference in pixel 2, which is in the center, if you center the image differently than I do.  If you want to match my solution, make sure to round to an integer after any divisions.

# %% [markdown]
# # Google CoLab Instructions
#
# If you are using Google CoLab, it will be necessary to mount your GDrive so that you can send your notebook during the submit process.  Running the following code will map your GDrive to ```/content/drive```.

# %%
try:
  from google.colab import drive, userdata
  drive.mount('/content/drive', force_remount=True)
  COLAB = True
  print("Note: using Google CoLab")
except:
  print("Note: not using Google CoLab")
  COLAB = False

# For Colab, add to your "Secrets" (key icon at the left)
key = userdata.get('T81_558_KEY')

# %% [markdown]
# # Assignment Submission Library
#
# Run the following code to install the assignment submission package (`jh_submit`). All of the submission, listing, and file-checking utilities used in this notebook live in this package.

# %%
# Assignment submission package
# !pip install https://s3.us-east-1.amazonaws.com/data.heatonresearch.com/library/jh_submit-0.1.0-py3-none-any.whl
import jh_submit

# %% [markdown]
# # Assignment #7 Sample Code
#
# The following code provides a starting point for this assignment.

# %%
# %matplotlib inline

import os
import pandas as pd
import io
import requests
import numpy as np
from scipy.stats import zscore
from PIL import Image, ImageFile
from matplotlib.pyplot import imshow
import requests
from io import BytesIO
import numpy as np

# You must identify your source file.  (modify for your local setup)
file="/content/drive/My Drive/Colab Notebooks/assignment_yourname_t81_558_class7.ipynb"  # Google CoLab
# file='C:\\Users\\jeffh\\projects\\t81_558_deep_learning\\assignments\\assignment_yourname_class7.ipynb'  # Windows
# file='/Users/jheaton/projects/t81_558_deep_learning/assignments/assignment_yourname_class7.ipynb'  # Mac/Linux

# Handle first image
url = "https://github.com/jeffheaton/t81_558_deep_learning/raw/master/photos/hickory_home.jpg"

## ... continue your code...

## Submit assignment

jh_submit.client.submit(source_file=file,data=[submit_img1,submit_img2],key=key,no=7, course='t81-558')
